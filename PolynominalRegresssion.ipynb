# %%
# %matplotlib inline
from pylab import *
import numpy as np
age = np.random.normal(40.0, 10.0, 1000)
height = 200 - (age + np.random.normal(20, 4, 1000)) / age

# %%
hist(age)
# Out:
# (array([ 16.,  56., 119., 207., 238., 194.,  97.,  55.,  15.,   3.]),
#  array([13.23846741, 19.2236465 , 25.20882559, 31.19400469, 37.17918378,
#         43.16436287, 49.14954197, 55.13472106, 61.11990015, 67.10507925,
#         73.09025834]),
#  <a list of 10 Patch objects>)

# %%
hist(height)
# Out:
# (array([  2.,   0.,   1.,   4.,   5.,  17.,  47., 199., 555., 170.]),
#  array([196.55576325, 196.78674418, 197.01772512, 197.24870605,
#         197.47968698, 197.71066791, 197.94164884, 198.17262977,
#         198.4036107 , 198.63459163, 198.86557256]),
#  <a list of 10 Patch objects>)

# %%
scatter(age, height)

# %%
x = np.array(age)
y = np.array(height)
p3 = np.poly1d(np.polyfit(x,y,3))

# %%
import matplotlib.pyplot as plt
xp = np.linspace(10,70,100)
plt.scatter(x,y)
plt.plot(xp,p3(xp),c='r')
plt.show()

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y,p3(x))
print(r2)
# Out:
# 0.7148060843815691
